# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\boston\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\boston\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime
now = datetime.datetime.now()

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
x=1
count=1
city_df=[]
lat=[] 
long=[]
Max_Temp=[]
Humidity=[]
Cloudiness=[]
Wind_Speed=[]
Country=[]
Date=[]

url= f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}&q="
city_responses= [ ]

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("Beginning Data Retrieval")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

for city in cities:
    if x >= 51: 
        count+= 1
        x=1
    try:
        city_data=requests.get(url + city).json()
        city_df.append(city_data['name'])
        lat.append(city_data['coord']['lat'])
        long.append(city_data['coord']['lon'])
        Max_Temp.append(city_data['main']['temp_max'])
        Humidity.append(city_data['main']["humidity"])
        Cloudiness.append(city_data["clouds"]['all'])
        Wind_Speed.append(city_data["wind"]['speed'])
        Country.append(city_data['sys']['country'])
        Date.append(city_data['dt'])
        city_responses.append(city_data)
        print(f"Processing Record {x} of set {count}|{city}")
        x+=1
    except: 
        print("City not found. Skipping... ")
        
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("Data Retrieval Complete ")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Beginning Data Retrieval
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Processing Record 1 of set 1|ushuaia
# Processing Record 2 of set 1|tual
# Processing Record 3 of set 1|rio grande
# Processing Record 4 of set 1|bayeux
# Processing Record 5 of set 1|narsaq
# Processing Record 6 of set 1|podhum
# Processing Record 7 of set 1|besskorbnaya
# Processing Record 8 of set 1|yellowknife
# Processing Record 9 of set 1|mataura
# Processing Record 10 of set 1|lebu
# Processing Record 11 of set 1|kapaa
# Processing Record 12 of set 1|lucea
# Processing Record 13 of set 1|hermanus
# Processing Record 14 of set 1|makakilo city
# Processing Record 15 of set 1|east london
# Processing Record 16 of set 1|punta arenas
# Processing Record 17 of set 1|new norfolk
# Processing Record 18 of set 1|port blair
# City not found. Skipping...
# Processing Record 19 of set 1|fort nelson
# City not found. Skipping...
# Processing Record 20 of set 1|puerto ayora
# Processing Record 21 of set 1|richards bay
# Processing Record 22 of set 1|thinadhoo
# Processing Record 23 of set 1|nhamunda
# Processing Record 24 of set 1|rikitea
# Processing Record 25 of set 1|hobart
# Processing Record 26 of set 1|zhanaozen
# Processing Record 27 of set 1|pandan
# Processing Record 28 of set 1|pevek
# Processing Record 29 of set 1|bani
# Processing Record 30 of set 1|riyadh
# Processing Record 31 of set 1|rafaela
# Processing Record 32 of set 1|belaya gora
# Processing Record 33 of set 1|fairbanks
# Processing Record 34 of set 1|den helder
# Processing Record 35 of set 1|manadhoo
# Processing Record 36 of set 1|tiksi
# Processing Record 37 of set 1|banda aceh
# Processing Record 38 of set 1|barrow
# Processing Record 39 of set 1|mar del plata
# Processing Record 40 of set 1|cape town
# Processing Record 41 of set 1|sikeston
# Processing Record 42 of set 1|pitogo
# Processing Record 43 of set 1|berlevag
# Processing Record 44 of set 1|chardara
# Processing Record 45 of set 1|port alfred
# Processing Record 46 of set 1|georgetown
# Processing Record 47 of set 1|bosaso
# Processing Record 48 of set 1|bluff
# Processing Record 49 of set 1|tougan
# Processing Record 50 of set 1|tautira
# Processing Record 1 of set 2|mahebourg
# Processing Record 2 of set 2|salalah
# Processing Record 3 of set 2|lafiagi
# Processing Record 4 of set 2|wainwright
# Processing Record 5 of set 2|thompson
# Processing Record 6 of set 2|guerrero negro
# Processing Record 7 of set 2|bengkulu
# Processing Record 8 of set 2|cherskiy
# Processing Record 9 of set 2|los algarrobos
# Processing Record 10 of set 2|saskylakh
# Processing Record 11 of set 2|saldanha
# Processing Record 12 of set 2|busselton
# Processing Record 13 of set 2|san cristobal
# Processing Record 14 of set 2|lorengau
# Processing Record 15 of set 2|avarua
# Processing Record 16 of set 2|the valley
# Processing Record 17 of set 2|boshnyakovo
# Processing Record 18 of set 2|esperance
# Processing Record 19 of set 2|ipixuna
# Processing Record 20 of set 2|ponta do sol
# Processing Record 21 of set 2|hilo
# Processing Record 22 of set 2|stryn
# Processing Record 23 of set 2|atuona
# Processing Record 24 of set 2|ancud
# Processing Record 25 of set 2|doha
# Processing Record 26 of set 2|cidreira
# Processing Record 27 of set 2|south lake tahoe
# Processing Record 28 of set 2|nikolskoye
# Processing Record 29 of set 2|bambanglipuro
# Processing Record 30 of set 2|arraial do cabo
# City not found. Skipping...
# Processing Record 31 of set 2|cayenne
# Processing Record 32 of set 2|zhigansk
# Processing Record 33 of set 2|waverley
# Processing Record 34 of set 2|havoysund
# Processing Record 35 of set 2|korla
# City not found. Skipping...
# Processing Record 36 of set 2|port elizabeth
# Processing Record 37 of set 2|bansang
# Processing Record 38 of set 2|calbuco
# Processing Record 39 of set 2|tuktoyaktuk
# Processing Record 40 of set 2|iqaluit
# City not found. Skipping...
# Processing Record 41 of set 2|tasiilaq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of set 2|isangel
# Processing Record 43 of set 2|touros
# Processing Record 44 of set 2|kulotino
# Processing Record 45 of set 2|neryungri
# Processing Record 46 of set 2|lesnyye polyany
# Processing Record 47 of set 2|petropavlovsk-kamchatskiy
# Processing Record 48 of set 2|harper
# Processing Record 49 of set 2|albany
# Processing Record 50 of set 2|cabo san lucas
# Processing Record 1 of set 3|tselinnoye
# Processing Record 2 of set 3|pringsewu
# Processing Record 3 of set 3|sioux lookout
# Processing Record 4 of set 3|chokurdakh
# Processing Record 5 of set 3|hithadhoo
# Processing Record 6 of set 3|sinop
# Processing Record 7 of set 3|kruisfontein
# Processing Record 8 of set 3|zeya
# Processing Record 9 of set 3|basco
# Processing Record 10 of set 3|aswan
# Processing Record 11 of set 3|airai
# Processing Record 12 of set 3|labuhan
# Processing Record 13 of set 3|san quintin
# City not found. Skipping...
# Processing Record 14 of set 3|baiyin
# Processing Record 15 of set 3|dikson
# Processing Record 16 of set 3|rantepao
# Processing Record 17 of set 3|flinders
# Processing Record 18 of set 3|khatanga
# Processing Record 19 of set 3|port macquarie
# Processing Record 20 of set 3|sitka
# City not found. Skipping...
# Processing Record 21 of set 3|mount gambier
# Processing Record 22 of set 3|huarmey
# Processing Record 23 of set 3|hoquiam
# Processing Record 24 of set 3|macomb
# Processing Record 25 of set 3|geraldton
# Processing Record 26 of set 3|caravelas
# Processing Record 27 of set 3|lompoc
# Processing Record 28 of set 3|kathmandu
# Processing Record 29 of set 3|nouadhibou
# Processing Record 30 of set 3|grand forks
# Processing Record 31 of set 3|coahuayana
# Processing Record 32 of set 3|hobyo
# Processing Record 33 of set 3|karaton
# City not found. Skipping...
# Processing Record 34 of set 3|itaparica
# Processing Record 35 of set 3|santa cruz
# Processing Record 36 of set 3|te anau
# Processing Record 37 of set 3|kihei
# City not found. Skipping...
# Processing Record 38 of set 3|omboue
# Processing Record 39 of set 3|adrar
# Processing Record 40 of set 3|butaritari
# Processing Record 41 of set 3|olga
# Processing Record 42 of set 3|malabo
# Processing Record 43 of set 3|kavaratti
# Processing Record 44 of set 3|vaini
# Processing Record 45 of set 3|katsuura
# Processing Record 46 of set 3|chuy
# Processing Record 47 of set 3|cairns
# Processing Record 48 of set 3|praxedis guerrero
# Processing Record 49 of set 3|manacapuru
# Processing Record 50 of set 3|liverpool
# Processing Record 1 of set 4|prado
# City not found. Skipping...
# Processing Record 2 of set 4|los llanos de aridane
# Processing Record 3 of set 4|souillac
# Processing Record 4 of set 4|paidha
# Processing Record 5 of set 4|saint-joseph
# Processing Record 6 of set 4|severo-kurilsk
# Processing Record 7 of set 4|tavda
# Processing Record 8 of set 4|dawei
# Processing Record 9 of set 4|maceio
# Processing Record 10 of set 4|esik
# Processing Record 11 of set 4|sept-iles
# Processing Record 12 of set 4|tessalit
# Processing Record 13 of set 4|shubarshi
# Processing Record 14 of set 4|tamiahua
# Processing Record 15 of set 4|codrington
# Processing Record 16 of set 4|fortuna
# Processing Record 17 of set 4|vila franca do campo
# City not found. Skipping...
# Processing Record 18 of set 4|zarubino
# Processing Record 19 of set 4|rio gallegos
# Processing Record 20 of set 4|provideniya
# Processing Record 21 of set 4|carnarvon
# Processing Record 22 of set 4|caticlan
# Processing Record 23 of set 4|dingle
# Processing Record 24 of set 4|grindavik
# Processing Record 25 of set 4|hamilton
# Processing Record 26 of set 4|longyearbyen
# Processing Record 27 of set 4|upernavik
# Processing Record 28 of set 4|shenjiamen
# Processing Record 29 of set 4|port-gentil
# Processing Record 30 of set 4|alofi
# Processing Record 31 of set 4|boca do acre
# Processing Record 32 of set 4|port augusta
# Processing Record 33 of set 4|ketchikan
# Processing Record 34 of set 4|sao filipe
# City not found. Skipping...
# Processing Record 35 of set 4|boffa
# Processing Record 36 of set 4|atar
# Processing Record 37 of set 4|colesberg
# Processing Record 38 of set 4|kayes
# Processing Record 39 of set 4|zhezkazgan
# Processing Record 40 of set 4|half moon bay
# Processing Record 41 of set 4|champerico
# Processing Record 42 of set 4|toamasina
# Processing Record 43 of set 4|kromy
# Processing Record 44 of set 4|amboasary
# Processing Record 45 of set 4|karratha
# Processing Record 46 of set 4|namie
# Processing Record 47 of set 4|minas
# Processing Record 48 of set 4|clyde river
# Processing Record 49 of set 4|castro
# Processing Record 50 of set 4|halifax
# City not found. Skipping...
# Processing Record 1 of set 5|vazante
# Processing Record 2 of set 5|vao
# Processing Record 3 of set 5|forecariah
# Processing Record 4 of set 5|la libertad
# Processing Record 5 of set 5|verin
# Processing Record 6 of set 5|sao jose da coroa grande
# Processing Record 7 of set 5|kabansk
# Processing Record 8 of set 5|saint george
# Processing Record 9 of set 5|alexandria
# Processing Record 10 of set 5|velikiy ustyug
# Processing Record 11 of set 5|karpathos
# Processing Record 12 of set 5|arcoverde
# Processing Record 13 of set 5|kuusamo
# Processing Record 14 of set 5|bredasdorp
# Processing Record 15 of set 5|bethel
# City not found. Skipping...
# Processing Record 16 of set 5|northam
# Processing Record 17 of set 5|ardalstangen
# Processing Record 18 of set 5|qaanaaq
# City not found. Skipping...
# Processing Record 19 of set 5|vestmannaeyjar
# Processing Record 20 of set 5|lagos
# Processing Record 21 of set 5|namibe
# Processing Record 22 of set 5|salta
# Processing Record 23 of set 5|nome
# Processing Record 24 of set 5|shimoda
# Processing Record 25 of set 5|rusne
# Processing Record 26 of set 5|sao lourenco da mata
# Processing Record 27 of set 5|lucelia
# Processing Record 28 of set 5|tiarei
# Processing Record 29 of set 5|caraballeda
# Processing Record 30 of set 5|klaksvik
# Processing Record 31 of set 5|camopi
# Processing Record 32 of set 5|lyaskelya
# Processing Record 33 of set 5|saint-pierre
# Processing Record 34 of set 5|faya
# Processing Record 35 of set 5|leningradskiy
# Processing Record 36 of set 5|olafsvik
# Processing Record 37 of set 5|eenhana
# Processing Record 38 of set 5|deputatskiy
# Processing Record 39 of set 5|hasaki
# Processing Record 40 of set 5|suntar
# Processing Record 41 of set 5|kharhial
# Processing Record 42 of set 5|berdigestyakh
# Processing Record 43 of set 5|bukama
# Processing Record 44 of set 5|vanavara
# Processing Record 45 of set 5|miri
# Processing Record 46 of set 5|gazojak
# Processing Record 47 of set 5|ulladulla
# Processing Record 48 of set 5|viedma
# Processing Record 49 of set 5|manggar
# Processing Record 50 of set 5|hami
# Processing Record 1 of set 6|ahipara
# City not found. Skipping...
# Processing Record 2 of set 6|tilichiki
# Processing Record 3 of set 6|naze
# Processing Record 4 of set 6|krasnyy chikoy
# Processing Record 5 of set 6|moose factory
# City not found. Skipping...
# Processing Record 6 of set 6|fernandez
# Processing Record 7 of set 6|chumikan
# Processing Record 8 of set 6|saint-philippe
# Processing Record 9 of set 6|aripuana
# Processing Record 10 of set 6|areosa
# Processing Record 11 of set 6|takoradi
# Processing Record 12 of set 6|ambilobe
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of set 6|augusto correa
# Processing Record 14 of set 6|komsomolskiy
# Processing Record 15 of set 6|pavlovsk
# Processing Record 16 of set 6|sorland
# Processing Record 17 of set 6|kautokeino
# Processing Record 18 of set 6|veraval
# Processing Record 19 of set 6|moyobamba
# Processing Record 20 of set 6|husavik
# Processing Record 21 of set 6|kaitangata
# Processing Record 22 of set 6|kananga
# Processing Record 23 of set 6|lagoa
# Processing Record 24 of set 6|tura
# Processing Record 25 of set 6|tecoman
# Processing Record 26 of set 6|sao joao da barra
# Processing Record 27 of set 6|bogale
# Processing Record 28 of set 6|aguimes
# Processing Record 29 of set 6|lincoln
# City not found. Skipping...
# Processing Record 30 of set 6|sukhobezvodnoye
# Processing Record 31 of set 6|safford
# City not found. Skipping...
# Processing Record 32 of set 6|gat
# Processing Record 33 of set 6|torbay
# Processing Record 34 of set 6|aguas vermelhas
# Processing Record 35 of set 6|taltal
# Processing Record 36 of set 6|palora
# Processing Record 37 of set 6|qaqortoq
# Processing Record 38 of set 6|beringovskiy
# City not found. Skipping...
# Processing Record 39 of set 6|san antonio
# Processing Record 40 of set 6|diamantino
# Processing Record 41 of set 6|sabang
# Processing Record 42 of set 6|kodiak
# Processing Record 43 of set 6|mehamn
# Processing Record 44 of set 6|bardiyah
# Processing Record 45 of set 6|sistranda
# Processing Record 46 of set 6|culebra
# Processing Record 47 of set 6|tiznit
# Processing Record 48 of set 6|balkanabat
# Processing Record 49 of set 6|sault sainte marie
# Processing Record 50 of set 6|kangaatsiaq
# Processing Record 1 of set 7|bourail
# Processing Record 2 of set 7|allapalli
# City not found. Skipping...
# Processing Record 3 of set 7|kjollefjord
# City not found. Skipping...
# Processing Record 4 of set 7|norman wells
# Processing Record 5 of set 7|bambous virieux
# Processing Record 6 of set 7|svetlaya
# Processing Record 7 of set 7|utrecht
# City not found. Skipping...
# Processing Record 8 of set 7|ilulissat
# Processing Record 9 of set 7|kirovsk
# Processing Record 10 of set 7|santa rosa
# Processing Record 11 of set 7|mizque
# City not found. Skipping...
# Processing Record 12 of set 7|changli
# Processing Record 13 of set 7|kilindoni
# Processing Record 14 of set 7|ibra
# Processing Record 15 of set 7|willmar
# Processing Record 16 of set 7|veshenskaya
# Processing Record 17 of set 7|xining
# Processing Record 18 of set 7|sarh
# Processing Record 19 of set 7|micheweni
# Processing Record 20 of set 7|progreso
# Processing Record 21 of set 7|milkovo
# Processing Record 22 of set 7|slave lake
# Processing Record 23 of set 7|chapais
# Processing Record 24 of set 7|nizhnevartovsk
# Processing Record 25 of set 7|chute-aux-outardes
# Processing Record 26 of set 7|tacana
# Processing Record 27 of set 7|jamestown
# Processing Record 28 of set 7|egvekinot
# Processing Record 29 of set 7|kununurra
# Processing Record 30 of set 7|zhangjiakou
# Processing Record 31 of set 7|senneterre
# City not found. Skipping...
# Processing Record 32 of set 7|kenai
# Processing Record 33 of set 7|bilma
# City not found. Skipping...
# Processing Record 34 of set 7|itarema
# Processing Record 35 of set 7|udachnyy
# Processing Record 36 of set 7|linxia
# Processing Record 37 of set 7|tucumcari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of set 7|teguldet
# Processing Record 39 of set 7|mogadishu
# Processing Record 40 of set 7|chenzhou
# City not found. Skipping...
# Processing Record 41 of set 7|sorong
# Processing Record 42 of set 7|mendi
# Processing Record 43 of set 7|khed brahma
# Processing Record 44 of set 7|otavi
# Processing Record 45 of set 7|poum
# Processing Record 46 of set 7|flin flon
# Processing Record 47 of set 7|ghanzi
# Processing Record 48 of set 7|soanierana ivongo
# Processing Record 49 of set 7|bintulu
# Processing Record 50 of set 7|gwadar
# Processing Record 1 of set 8|kui buri
# Processing Record 2 of set 8|fergus falls
# Processing Record 3 of set 8|lima
# Processing Record 4 of set 8|candolim
# Processing Record 5 of set 8|chicama
# Processing Record 6 of set 8|pemangkat
# Processing Record 7 of set 8|kysyl-syr
# Processing Record 8 of set 8|panguna
# Processing Record 9 of set 8|yatou
# City not found. Skipping...
# Processing Record 10 of set 8|noumea
# Processing Record 11 of set 8|indramayu
# Processing Record 12 of set 8|ribeira grande
# Processing Record 13 of set 8|calama
# Processing Record 14 of set 8|talnakh
# Processing Record 15 of set 8|ewa beach
# Processing Record 16 of set 8|catamarca
# Processing Record 17 of set 8|coihaique
# Processing Record 18 of set 8|isfara
# Processing Record 19 of set 8|davila
# Processing Record 20 of set 8|haimen
# Processing Record 21 of set 8|sydney mines
# City not found. Skipping...
# Processing Record 22 of set 8|ust-nera
# City not found. Skipping...
# Processing Record 23 of set 8|safakulevo
# Processing Record 24 of set 8|dongsheng
# Processing Record 25 of set 8|paita
# Processing Record 26 of set 8|pacific grove
# Processing Record 27 of set 8|irtyshskiy
# City not found. Skipping...
# Processing Record 28 of set 8|kalabo
# Processing Record 29 of set 8|broome
# Processing Record 30 of set 8|boueni
# City not found. Skipping...
# Processing Record 31 of set 8|opunake
# Processing Record 32 of set 8|tlacotepec
# Processing Record 33 of set 8|coquimbo
# Processing Record 34 of set 8|inta
# Processing Record 35 of set 8|san juan
# City not found. Skipping...
# Processing Record 36 of set 8|verkhnyaya inta
# Processing Record 37 of set 8|kutum
# Processing Record 38 of set 8|likasi
# Processing Record 39 of set 8|berberati
# Processing Record 40 of set 8|aksu
# Processing Record 41 of set 8|anchorage
# Processing Record 42 of set 8|aykhal
# Processing Record 43 of set 8|salamanca
# City not found. Skipping...
# Processing Record 44 of set 8|coolum beach
# Processing Record 45 of set 8|vanimo
# Processing Record 46 of set 8|vilhena
# Processing Record 47 of set 8|healdsburg
# Processing Record 48 of set 8|cuenca
# Processing Record 49 of set 8|nabire
# Processing Record 50 of set 8|durban
# Processing Record 1 of set 9|bandar-e anzali
# Processing Record 2 of set 9|staryy oskol
# Processing Record 3 of set 9|huesca
# Processing Record 4 of set 9|huicungo
# Processing Record 5 of set 9|melfi
# Processing Record 6 of set 9|broken hill
# Processing Record 7 of set 9|weyburn
# Processing Record 8 of set 9|port lincoln
# City not found. Skipping...
# Processing Record 9 of set 9|kavieng
# Processing Record 10 of set 9|joshimath
# Processing Record 11 of set 9|malartic
# Processing Record 12 of set 9|mwinilunga
# Processing Record 13 of set 9|paragominas
# Processing Record 14 of set 9|jiangkou
# Processing Record 15 of set 9|licheng
# Processing Record 16 of set 9|gizo
# Processing Record 17 of set 9|okhotsk
# Processing Record 18 of set 9|vostok
# Processing Record 19 of set 9|kismayo
# Processing Record 20 of set 9|palmer
# Processing Record 21 of set 9|senanga
# Processing Record 22 of set 9|mana
# Processing Record 23 of set 9|praia da vitoria
# Processing Record 24 of set 9|paamiut
# Processing Record 25 of set 9|luderitz
# City not found. Skipping...
# Processing Record 26 of set 9|nemuro
# Processing Record 27 of set 9|salinas
# Processing Record 28 of set 9|caceres
# Processing Record 29 of set 9|srednekolymsk
# Processing Record 30 of set 9|nyurba
# Processing Record 31 of set 9|sol-iletsk
# Processing Record 32 of set 9|bathsheba
# Processing Record 33 of set 9|alice springs
# Processing Record 34 of set 9|koslan
# Processing Record 35 of set 9|seymchan
# Processing Record 36 of set 9|gimli
# Processing Record 37 of set 9|kimberley
# Processing Record 38 of set 9|zhanakorgan
# Processing Record 39 of set 9|pontes e lacerda
# Processing Record 40 of set 9|anadyr
# Processing Record 41 of set 9|kungurtug
# Processing Record 42 of set 9|balkhash
# Processing Record 43 of set 9|leninskoye
# Processing Record 44 of set 9|clarence town
# Processing Record 45 of set 9|esil
# Processing Record 46 of set 9|vardo
# Processing Record 47 of set 9|tuatapere
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of set 9|churapcha
# Processing Record 49 of set 9|liwale
# Processing Record 50 of set 9|sovetskiy
# City not found. Skipping...
# Processing Record 1 of set 10|henties bay
# Processing Record 2 of set 10|alpena
# Processing Record 3 of set 10|menongue
# Processing Record 4 of set 10|kirakira
# Processing Record 5 of set 10|padang
# Processing Record 6 of set 10|mount isa
# Processing Record 7 of set 10|bassar
# Processing Record 8 of set 10|torez
# Processing Record 9 of set 10|ossora
# Processing Record 10 of set 10|quelimane
# Processing Record 11 of set 10|nanortalik
# Processing Record 12 of set 10|suez
# Processing Record 13 of set 10|prince rupert
# Processing Record 14 of set 10|dingli
# Processing Record 15 of set 10|saint-raphael
# Processing Record 16 of set 10|rocha
# Processing Record 17 of set 10|acari
# Processing Record 18 of set 10|yunhe
# Processing Record 19 of set 10|terrak
# Processing Record 20 of set 10|victor harbor
# Processing Record 21 of set 10|imeni poliny osipenko
# Processing Record 22 of set 10|metro
# Processing Record 23 of set 10|bonthe
# City not found. Skipping...
# Processing Record 24 of set 10|avera
# Processing Record 25 of set 10|sahuaripa
# Processing Record 26 of set 10|eldorado
# Processing Record 27 of set 10|oksbol
# Processing Record 28 of set 10|sibu
# Processing Record 29 of set 10|leinefelde
# Processing Record 30 of set 10|quimper
# Processing Record 31 of set 10|victoria
# Processing Record 32 of set 10|jatai
# Processing Record 33 of set 10|tafalla
# Processing Record 34 of set 10|porto walter
# Processing Record 35 of set 10|kalocsa
# Processing Record 36 of set 10|kondopoga
# Processing Record 37 of set 10|jinchang
# Processing Record 38 of set 10|kosonsoy
# Processing Record 39 of set 10|ankang
# City not found. Skipping...
# Processing Record 40 of set 10|sinnamary
# Processing Record 41 of set 10|severo-yeniseyskiy
# Processing Record 42 of set 10|olean
# City not found. Skipping...
# Processing Record 43 of set 10|aksarka
# Processing Record 44 of set 10|zhuhai
# Processing Record 45 of set 10|camana
# Processing Record 46 of set 10|marzuq
# Processing Record 47 of set 10|namatanai
# Processing Record 48 of set 10|cap malheureux
# Processing Record 49 of set 10|mao
# Processing Record 50 of set 10|san policarpo
# City not found. Skipping...
# Processing Record 1 of set 11|grand gaube
# City not found. Skipping...
# Processing Record 2 of set 11|sao gabriel da cachoeira
# Processing Record 3 of set 11|mezen
# Processing Record 4 of set 11|katangli
# Processing Record 5 of set 11|aljezur
# Processing Record 6 of set 11|cabano
# Processing Record 7 of set 11|sola
# Processing Record 8 of set 11|kerema
# Processing Record 9 of set 11|toronto
# Processing Record 10 of set 11|viesca
# Processing Record 11 of set 11|rawa mazowiecka
# City not found. Skipping...
# Processing Record 12 of set 11|port hedland
# Processing Record 13 of set 11|yeniseysk
# Processing Record 14 of set 11|sobolevo
# Processing Record 15 of set 11|cabedelo
# Processing Record 16 of set 11|margate
# Processing Record 17 of set 11|sao felix do xingu
# Processing Record 18 of set 11|sao lourenco do sul
# Processing Record 19 of set 11|araouane
# Processing Record 20 of set 11|noormarkku
# Processing Record 21 of set 11|hofn
# Processing Record 22 of set 11|korostyshiv
# Processing Record 23 of set 11|memari
# Processing Record 24 of set 11|westport
# Processing Record 25 of set 11|portland
# Processing Record 26 of set 11|larnaca
# City not found. Skipping...
# Processing Record 27 of set 11|ayolas
# Processing Record 28 of set 11|boralday
# Processing Record 29 of set 11|gualaquiza
# Processing Record 30 of set 11|ulaangom
# Processing Record 31 of set 11|gaoua
# Processing Record 32 of set 11|porto novo
# Processing Record 33 of set 11|maxixe
# City not found. Skipping...
# Processing Record 34 of set 11|vyartsilya
# Processing Record 35 of set 11|bandarbeyla
# Processing Record 36 of set 11|eureka
# Processing Record 37 of set 11|ornskoldsvik
# Processing Record 38 of set 11|belmonte
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Data Retrieval Complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#output_data_file = ".../WeatherPy/cities.csv"
output_data_file = "output_data/cities.csv"

# %%
city_weather=pd.DataFrame({
    "City":city_df,
    "Latitude":lat,
    "Longitute": long,
    "Max Temperature": Max_Temp,
    "Humidity": Humidity,
    "Cloudiness": Cloudiness,
    "Wind Speed": Wind_Speed,
    "Country": Country,
    "Date":Date,
})

# Option 2
#   quantile(d$Point, 0.95)
#   95% 
#   5800

#   df %>% filter(Point < quantile(df$Point, 0.95))
#   Group Point
#   1     B  5000
#   2     C  1000
#   3     D   100
#   4     F    70

# ----------------------------------------
# Option 1
# quantile(d$Point, 0.95)
# 95% 
# 5800 

# d[d$Point < quantile(d$Point, 0.95), ]
# Group Point
# 2     B  5000
# 3     C  1000
# 4     D   100
# 5     F    70

# -----------------------------------------
city_weather.head()
# Out:
#          City  Latitude  Longitute  Max Temperature  Humidity  Cloudiness  \
# 0     Ushuaia    -54.80     -68.30            24.80       100           0
# 1        Tual     -5.67     132.75            78.69        84          72
# 2  Rio Grande    -32.03     -52.10            62.01        90          27
# 3      Bayeux     -7.12     -34.93            73.36        89          18
# 4      Narsaq     60.92     -46.05            50.00        61          56
#
#    Wind Speed Country        Date
# 0        3.80      AR  1595220527
# 1       19.60      ID  1595220527
# 2        7.29      BR  1595220527
# 3        9.24      BR  1595220527
# 4        4.70      GL  1595220527

# %% [markdown]
# ##### Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#city_weather.count()

# %%
#city_weather=city_weather[city_weather["Humidity"]>=100]
#city_weather.count()

# %%
#  Get the indices of cities that have humidity over 100%.

#city_weather["Humidity"].max()

city_weather=city_weather[city_weather["Humidity"] <= 100]
city_weather.describe()
# Out:
#          Latitude   Longitute  Max Temperature    Humidity  Cloudiness  \
# count  538.000000  538.000000       538.000000  538.000000  538.000000
# mean    19.740112   19.310706        69.021580   71.284387   50.241636
# std     33.852164   90.372372        13.728043   21.494250   37.792696
# min    -54.800000 -179.170000        24.800000    5.000000    0.000000
# 25%     -8.667500  -59.992500        60.010000   60.000000    8.250000
# 50%     21.335000   24.545000        69.800000   76.000000   53.500000
# 75%     49.660000  102.245000        79.000000   87.750000   90.000000
# max     78.220000  179.320000       102.200000  100.000000  100.000000
#
#        Wind Speed          Date
# count  538.000000  5.380000e+02
# mean     7.325242  1.595221e+09
# std      4.823713  7.098200e+01
# min      0.290000  1.595220e+09
# 25%      3.452500  1.595221e+09
# 50%      6.275000  1.595221e+09
# 75%      9.690000  1.595221e+09
# max     32.210000  1.595221e+09

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index. ? 
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

city_weather=city_weather[city_weather["Humidity"] <= 101]

city_weather=pd.DataFrame({
    "City":city_df,
    "Latitude":lat,
    "Longitute": long,
    "Max Temperature": Max_Temp,
    "Humidity": Humidity,
    "Cloudiness": Cloudiness,
    "Wind Speed": Wind_Speed,
    "County": Country,
    "Date":Date,
})



city_weather.head()
# Out:
#          City  Latitude  Longitute  Max Temperature  Humidity  Cloudiness  \
# 0     Ushuaia    -54.80     -68.30            24.80       100           0
# 1        Tual     -5.67     132.75            78.69        84          72
# 2  Rio Grande    -32.03     -52.10            62.01        90          27
# 3      Bayeux     -7.12     -34.93            73.36        89          18
# 4      Narsaq     60.92     -46.05            50.00        61          56
#
#    Wind Speed County        Date
# 0        3.80     AR  1595220527
# 1       19.60     ID  1595220527
# 2        7.29     BR  1595220527
# 3        9.24     BR  1595220527
# 4        4.70     GL  1595220527

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
city_weather.to_csv("Clean_City_Data.csv")

# city_weather.to_csv(WeatherPy_file, index_label = "clean_city_data")
#output_data_file = "output_data/cities.csv"
#city_weather.to_csv(output_data_file, index_label = "clean_city_data")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
import datetime
now = datetime.datetime.now()

latitude = city_weather["Latitude"]
Max_temp = city_weather["Max Temperature"]

plt.scatter(latitude, Max_temp, marker="o", facecolors = "steelblue", edgecolor = 'black')

plt.grid()

#plt.title(f "City Latitude vs Max Temperature {datetime.now().strftime('%m-%d-%Y')}")
#print ("Current date and time : ")
#print (now.strftime("%Y-%m-%d %H:%M:%S"))

plt.title ("City Latitude vs Max Temperature 07/19/2020")
plt.xlabel ("City Latitude")
plt.ylabel ("Max Temperature")
plt.savefig ("Temp_vs_Lat.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = city_weather["Latitude"]
Humidity = city_weather["Humidity"]

plt.scatter(latitude, Humidity, marker="o", facecolors = "steelblue", edgecolor = 'black')

plt.grid()
plt.title ("City Latitude vs Humidity 07/19/2020")
plt.xlabel ("City Latitude")
plt.ylabel ("Humidity")
plt.savefig ("Humidity_vs_Lat.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = city_weather["Latitude"]
Cloudiness = city_weather["Cloudiness"]

plt.scatter(latitude, Cloudiness, marker="o", facecolors = "steelblue", edgecolor = 'black')

plt.grid()
plt.title ("City Latitude vs Cloudiness 07/19/2020")
plt.xlabel ("City Latitude")
plt.ylabel ("Cloudiness")
plt.savefig ("Cloudiness_vs_Lat.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = city_weather["Latitude"]
Wind_Speed = city_weather["Wind Speed"]

plt.scatter(latitude, Wind_Speed, marker="o", facecolors = "steelblue", edgecolor = 'black')

plt.grid()
plt.title ("City Latitude vs Wind Speed 07/19/2020")
plt.xlabel ("City Latitude")
plt.ylabel ("Wind Speed")
plt.savefig ("Wind Speed_vs_Lat.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots (this was a nightmare)

# %%
# Create Northern and Southern Hemisphere DataFrames
#plt.plot(x, m*x + b)
Northern_df = city_weather[city_weather["Latitude"]>0]
Southern_df = city_weather[city_weather["Latitude"]<0]

# %%
def plot_linear_regression(x,y,title_coordinates, text_coordinates):
    
    (slope,intercept,rvalue,pvalue,stderr) = linregress (x,y)
    regress_values = x*slope + intercept
    
    #line_eq= f"y{round(slope,1)}x + {round(intercept,2)}"
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x, y, marker="o", facecolors="steelblue", edgecolor = 'black')
    plt.plot (x,regress_values, color = "blueviolet")
    plt.annotate (line_eq, (5,10), color= "blueviolet" ,fontsize = 15)
    plt.xlabel("Latitude")
    plt.ylabel ("Temperature")
    plt.title ("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
    plt.grid()
    #plt.ylim(25,120)
    #plt.xlim(-5,82.5)
    
    #plt.show()
#Added a grid because it adds a little more razzle dazzle and it keeps the same format from the previous charts
#Basically its there for continueity (spl?) 

    
    print(f"The r-squared IS: {rvalue**2}")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plot_linear_regression(Northern_df["Latitude"], Northern_df["Max Temperature"], "Max Temperature",(10,30))
plt.ylim(25,120)
plt.xlim(-5,82.5)
# Out:
# The r-squared IS: 0.41974073186648536
# (-5, 82.5)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Latitude"], Southern_df["Max Temperature"], "Max Temperature", (10,30) )
# Out:
# The r-squared IS: 0.48323151028023315

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plot_linear_regression(Northern_df["Latitude"], Northern_df["Humidity"], "Humidity", (10,30) )
# Out:
# The r-squared IS: 0.0010956062566825795

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Latitude"], Southern_df["Humidity"], "Humidity", (10,30) )
# Out:
# The r-squared IS: 0.0011878232201204771

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plot_linear_regression(Northern_df["Latitude"], Northern_df["Cloudiness"], "Cloudiness", (10,30) )
# Out:
# The r-squared IS: 0.00023236064021945593

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Latitude"], Southern_df["Cloudiness"], "Cloudiness", (10,30) )
# Out:
# The r-squared IS: 0.010098755605758425

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plot_linear_regression(Northern_df["Latitude"], Northern_df["Wind Speed"], "Wind Speed", (10,30) )
# Out:
# The r-squared IS: 0.014573761583135298

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Latitude"], Southern_df["Wind Speed"], "Wind Speed", (10,30) )
# Out:
# The r-squared IS: 0.003885020352697657

# %%
#If anyone reads this can you explain why the linear regression equation only shows up on some of the graphs
#and not any of the others?
